# %%
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot as plt

# %%
import os, sys
p = os.path.abspath('../..')
if p not in sys.path:
    sys.path.append(p)

from project.data.make_steps import make_data_dict, step_detection

# %%
data_dict = make_data_dict('00010100_s001_t000')
steps = step_detection(data_dict, 'FP1')
step1 = steps[0]
data = data_dict['FP1'][step1[0]:step1[1] - 10000]
print(data)
# Out:
# [ 3.84556184e-05  3.67771529e-05  3.40305730e-05 ... -2.28846657e-05
#  -2.33424290e-05 -2.05958491e-05]

# %%
import numpy as np
amplified_data = data * np.power(10, 5)
plt.plot(amplified_data)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame(data=amplified_data)
print(df)
roll_mean = df.rolling(window=10000).mean() # use hmm to determine window sizes??
roll_std = df.rolling(window=10000).std()
print(roll_mean)
plt.clf()
plt.plot(amplified_data)
plt.plot(roll_mean)
plt.plot(roll_std)
plt.show()
# Out:
#                0
# 0       3.845562
# 1       3.677715
# 2       3.403057
# 3       3.296246
# 4       3.219952
# ...          ...
# 157861 -2.029067
# 157862 -2.486831
# 157863 -2.288467
# 157864 -2.334243
# 157865 -2.059585
#
# [157866 rows x 1 columns]
#                0
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 157861  0.214197
# 157862  0.214080
# 157863  0.213985
# 157864  0.213886
# 157865  0.213834
#
# [157866 rows x 1 columns]

# %%
from statsmodels.tsa.stattools import adfuller
dickey_fuller = adfuller(amplified_data)

# %%
print('ADF Statistic: %f' % dickey_fuller[0])
print('p-value: %f' % dickey_fuller[1])
print('Critical Values:')
for key, value in dickey_fuller[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -12.303966
# p-value: 0.000000
# Critical Values:
# 	1%: -3.430
# 	5%: -2.862
# 	10%: -2.567

# %%
from statsmodels.tsa.stattools import acf,pacf
lag_acf = acf(amplified_data, nlags=1000)
lag_pacf = pacf(amplified_data, nlags=20, method='ols')
plt.clf()
plt.plot(lag_acf)
plt.show()
plt.plot(lag_pacf)
plt.show()
# Out:
# /Users/ishan/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:572: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning

# %%
from statsmodels.tsa.arima_model import ARIMA
ar_model = ARIMA(amplified_data, order=(2,2,0))
ar_results = ar_model.fit(disp=True)
plt.plot(amplified_data)
plt.plot(ar_results.fittedvalues)
plt.show()
print(f"Residual: {sum((ar_results.fittedvalues - amplified_data[0:-2])**2)}")
# Out:
# Residual: 1848375.6477794822

# %%
ma_model = ARIMA(amplified_data, order=(0,0,700))
ma_results = ar_model.fit(disp=True)
plt.plot(amplified_data)
plt.plot(ma_results.fittedvalues)
plt.show()
print(f"Residual: {sum((ar_results.fittedvalues - amplified_data)**2)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-2675e01945c9> in <module>
#       4 plt.plot(ma_results.fittedvalues)
#       5 plt.show()
# ----> 6 print(f"Residual: {sum((ar_results.fittedvalues - amplified_data)**2)}")
#
# ValueError: operands could not be broadcast together with shapes (157864,) (157866,)

# %%
arma_model = ARIMA(amplified_data, order=(2,1,700))
arma_results = ar_model.fit(disp=True)
plt.plot(amplified_data)
plt.plot(arma_results.fittedvalues)
plt.show()
print(f"Residual: {sum((ar_results.fittedvalues - amplified_data)**2)}")
# Out:
# Residual: 47047.427891486135

# %%
arma_results.plot_predict(1,2 * len(amplified_data))
